# %%
menu = {
    "Paneer Tikka": {"category": "Starters", "price": 180.0, "available": True},
    "Chicken Wings": {"category": "Starters", "price": 220.0, "available": False},
    "Veg Soup": {"category": "Starters", "price": 120.0, "available": True},
    "Butter Chicken": {"category": "Mains", "price": 320.0, "available": True},
    "Dal Tadka": {"category": "Mains", "price": 180.0, "available": True},
    "Veg Biryani": {"category": "Mains", "price": 250.0, "available": True},
    "Garlic Naan": {"category": "Mains", "price": 40.0, "available": True},
    "Gulab Jamun": {"category": "Desserts", "price": 90.0, "available": True},
    "Rasgulla": {"category": "Desserts", "price": 80.0, "available": True},
    "Ice Cream": {"category": "Desserts", "price": 110.0, "available": False}
}

# get categories
cats = []

for item in menu:
    c = menu[item]["category"]
    if c not in cats:
        cats.append(c)

# print menu
for c in cats:
    print("=====", c, "=====")

    for item in menu:
        if menu[item]["category"] == c:
            price = menu[item]["price"]
            avail = menu[item]["available"]

            if avail:
                status = "[Available]"
            else:
                status = "[Unavailable]"

            # simple spacing
            print(item.ljust(18), "₹" + format(price, ".2f"), status)

    print()


print("------------------")

# total items
print("Total items:", len(menu))

# available items
count = 0
for item in menu:
    if menu[item]["available"]:
        count += 1

print("Available items:", count)

# most expensive
max_price = 0
max_item = ""

for item in menu:
    if menu[item]["price"] > max_price:
        max_price = menu[item]["price"]
        max_item = item

print("Most expensive:", max_item, "₹" + str(max_price))

# under 150
print("\nItems under ₹150:")

for item in menu:
    if menu[item]["price"] < 150:
        print(item, "₹" + str(menu[item]["price"]))
# Out:
# ===== Starters =====
# Paneer Tikka       ₹180.00 [Available]
# Chicken Wings      ₹220.00 [Unavailable]
# Veg Soup           ₹120.00 [Available]
#
# ===== Mains =====
# Butter Chicken     ₹320.00 [Available]
# Dal Tadka          ₹180.00 [Available]
# Veg Biryani        ₹250.00 [Available]
# Garlic Naan        ₹40.00 [Available]
#
# ===== Desserts =====
# Gulab Jamun        ₹90.00 [Available]
# Rasgulla           ₹80.00 [Available]
# Ice Cream          ₹110.00 [Unavailable]
#
# ------------------
# Total items: 10
# Available items: 8
# Most expensive: Butter Chicken ₹320.0
#
# Items under ₹150:
# Veg Soup ₹120.0
# Garlic Naan ₹40.0
# Gulab Jamun ₹90.0
# Rasgulla ₹80.0
# Ice Cream ₹110.0

# %%
cart = []

# function to add item
def add_item(name, qty):
    if name not in menu:
        print(name, "not in menu")
        return

    if menu[name]["available"] == False:
        print(name, "is not available")
        return

    # check if already in cart
    found = False
    for c in cart:
        if c["item"] == name:
            c["quantity"] += qty
            found = True

    if found == False:
        cart.append({
            "item": name,
            "quantity": qty,
            "price": menu[name]["price"]
        })

# remove item
def remove_item(name):
    found = False
    for c in cart:
        if c["item"] == name:
            cart.remove(c)
            found = True
            break

    if found == False:
        print(name, "not in cart")

# print cart
def show_cart():
    print("\nCart:")
    for c in cart:
        print(c["item"], "x", c["quantity"])
    if len(cart) == 0:
        print("Cart is empty")

# ------------------ SIMULATION ------------------

add_item("Paneer Tikka", 2)
show_cart()

add_item("Gulab Jamun", 1)
show_cart()

add_item("Paneer Tikka", 1)
show_cart()

add_item("Mystery Burger", 1)
show_cart()

add_item("Chicken Wings", 1)
show_cart()

remove_item("Gulab Jamun")
show_cart()

# ------------------ BILL ------------------

print("\n========== Order Summary ==========")

subtotal = 0

for c in cart:
    total = c["quantity"] * c["price"]
    subtotal += total
    print(c["item"], "x"+str(c["quantity"]), "₹", total)

print("------------------------------------")

gst = subtotal * 0.05
total_pay = subtotal + gst

print("Subtotal:", subtotal)
print("GST (5%):", round(gst, 2))
print("Total Payable:", round(total_pay, 2))

print("====================================")
# Out:
# Cart:
# Paneer Tikka x 2
#
# Cart:
# Paneer Tikka x 2
# Gulab Jamun x 1
#
# Cart:
# Paneer Tikka x 3
# Gulab Jamun x 1
# Mystery Burger not in menu
#
# Cart:
# Paneer Tikka x 3
# Gulab Jamun x 1
# Chicken Wings is not available
#
# Cart:
# Paneer Tikka x 3
# Gulab Jamun x 1
#
# Cart:
# Paneer Tikka x 3
#
# ========== Order Summary ==========
# Paneer Tikka x3 ₹ 540.0
# ------------------------------------
# Subtotal: 540.0
# GST (5%): 27.0
# Total Payable: 567.0
# ...

# %%
inventory = {
    "Paneer Tikka": {"stock": 10, "reorder_level": 3},
    "Gulab Jamun": {"stock": 5, "reorder_level": 2}
}
cart = [
    {"item": "Paneer Tikka", "quantity": 3, "price": 180.0}
]
import copy

# make backup
inventory_backup = copy.deepcopy(inventory)

# change one value
inventory["Paneer Tikka"]["stock"] = 5

print("Inventory:", inventory["Paneer Tikka"]["stock"])
print("Backup:", inventory_backup["Paneer Tikka"]["stock"])

# restore
inventory = copy.deepcopy(inventory_backup)

print("\nRestored:", inventory["Paneer Tikka"]["stock"])


# update stock using cart
print("\nUpdating stock...")

for c in cart:
    name = c["item"]
    qty = c["quantity"]

    if name in inventory:
        stock = inventory[name]["stock"]

        if stock >= qty:
            inventory[name]["stock"] = stock - qty
        else:
            print("Not enough stock for", name)
            inventory[name]["stock"] = 0


# reorder alert
print("\nReorder Alerts:")

for item in inventory:
    stock = inventory[item]["stock"]
    level = inventory[item]["reorder_level"]

    if stock <= level:
        print(item, "-", stock, "left (reorder level:", level, ")")


# final check
print("\nFinal Inventory:", inventory)
print("\nBackup Inventory:", inventory_backup)
# Out:
# Inventory: 5
# Backup: 10
#
# Restored: 10
#
# Updating stock...
#
# Reorder Alerts:
#
# Final Inventory: {'Paneer Tikka': {'stock': 7, 'reorder_level': 3}, 'Gulab Jamun': {'stock': 5, 'reorder_level': 2}}
#
# Backup Inventory: {'Paneer Tikka': {'stock': 10, 'reorder_level': 3}, 'Gulab Jamun': {'stock': 5, 'reorder_level': 2}}

# %%
sales_log = {
    "2025-01-01": [
        {"order_id": 1, "items": ["Paneer Tikka", "Garlic Naan"], "total": 220.0},
        {"order_id": 2, "items": ["Gulab Jamun", "Veg Soup"], "total": 210.0},
        {"order_id": 3, "items": ["Butter Chicken", "Garlic Naan"], "total": 360.0},
    ],
    "2025-01-02": [
        {"order_id": 4, "items": ["Dal Tadka", "Garlic Naan"], "total": 220.0},
        {"order_id": 5, "items": ["Veg Biryani", "Gulab Jamun"], "total": 340.0},
    ],
    "2025-01-03": [
        {"order_id": 6, "items": ["Paneer Tikka", "Rasgulla"], "total": 260.0},
        {"order_id": 7, "items": ["Butter Chicken", "Veg Biryani"], "total": 570.0},
        {"order_id": 8, "items": ["Garlic Naan", "Gulab Jamun"], "total": 130.0},
    ],
    "2025-01-04": [
        {"order_id": 9, "items": ["Dal Tadka", "Garlic Naan", "Rasgulla"], "total": 300.0},
        {"order_id": 10, "items": ["Paneer Tikka", "Gulab Jamun"], "total": 270.0},
    ],
}
# revenue per day
print("Revenue per day:\n")

for d in sales_log:
    total = 0
    for o in sales_log[d]:
        total = total + o["total"]
    print(d, total)


# best day
max_day = ""
max_total = 0

for d in sales_log:
    total = 0
    for o in sales_log[d]:
        total = total + o["total"]

    if total > max_total:
        max_total = total
        max_day = d

print("\nBest Day:", max_day, max_total)


# most ordered item
count = {}

for d in sales_log:
    for o in sales_log[d]:
        for item in o["items"]:
            if item in count:
                count[item] += 1
            else:
                count[item] = 1

max_item = ""
max_c = 0

for item in count:
    if count[item] > max_c:
        max_c = count[item]
        max_item = item

print("\nMost Ordered:", max_item, max_c)


# add new day
sales_log["2025-01-05"] = [
    {"order_id": 11, "items": ["Butter Chicken", "Gulab Jamun", "Garlic Naan"], "total": 490.0},
    {"order_id": 12, "items": ["Paneer Tikka", "Rasgulla"], "total": 260.0}
]


# print again
print("\nUpdated Revenue:\n")

for d in sales_log:
    total = 0
    for o in sales_log[d]:
        total = total + o["total"]
    print(d, total)


# best day again
max_day = ""
max_total = 0

for d in sales_log:
    total = 0
    for o in sales_log[d]:
        total = total + o["total"]

    if total > max_total:
        max_total = total
        max_day = d

print("\nNew Best Day:", max_day, max_total)


# numbered orders
print("\nAll Orders:\n")

i = 1
for d in sales_log:
    for o in sales_log[d]:
        items = ", ".join(o["items"])
        print(i, ".", "[" + d + "] Order #" + str(o["order_id"]),
              "- ₹" + str(o["total"]), "- Items:", items)
        i += 1
# Out:
# Revenue per day:
#
# 2025-01-01 790.0
# 2025-01-02 560.0
# 2025-01-03 960.0
# 2025-01-04 570.0
#
# Best Day: 2025-01-03 960.0
#
# Most Ordered: Garlic Naan 5
#
# Updated Revenue:
#
# 2025-01-01 790.0
# 2025-01-02 560.0
# 2025-01-03 960.0
# 2025-01-04 570.0
# 2025-01-05 750.0
#
# New Best Day: 2025-01-03 960.0
#
# All Orders:
#
# 1 . [2025-01-01] Order #1 - ₹220.0 - Items: Paneer Tikka, Garlic Naan
# 2 . [2025-01-01] Order #2 - ₹210.0 - Items: Gulab Jamun, Veg Soup
# 3 . [2025-01-01] Order #3 - ₹360.0 - Items: Butter Chicken, Garlic Naan
# 4 . [2025-01-02] Order #4 - ₹220.0 - Items: Dal Tadka, Garlic Naan
# 5 . [2025-01-02] Order #5 - ₹340.0 - Items: Veg Biryani, Gulab Jamun
# 6 . [2025-01-03] Order #6 - ₹260.0 - Items: Paneer Tikka, Rasgulla
# 7 . [2025-01-03] Order #7 - ₹570.0 - Items: Butter Chicken, Veg Biryani
# 8 . [2025-01-03] Order #8 - ₹130.0 - Items: Garlic Naan, Gulab Jamun
# 9 . [2025-01-04] Order #9 - ₹300.0 - Items: Dal Tadka, Garlic Naan, Rasgulla
# ...
